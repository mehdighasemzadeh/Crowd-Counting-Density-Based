# %%
#========= install torch ================
# !pip install torch==1.7.1+cu101 torchvision==0.8.2+cu101 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 735.4/735.4 MB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 68.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 1.13.1+cu116
#     Uninstalling torch-1.13.1+cu116:
#       Successfully uninstalled torch-1.13.1+cu116
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.14.1+cu116
#     Uninstalling torchvision-0.14.1+cu116:
#       Successfully uninstalled torchvision-0.14.1+cu116
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.14.1 requires torch==1.13.1, but you have torch 1.7.1+cu101 which is incompatible.
# ...

# %%
#=== connect to google drive ========
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#==== download codes from github =======
# !git clone https://github.com/mehdighasemzadeh/Crowd-Counting-Density-Based.git
# Out:
# Cloning into 'Crowd-Counting-Density-Based'...
# remote: Enumerating objects: 44, done.
# remote: Total 44 (delta 0), reused 0 (delta 0), pack-reused 44
# Unpacking objects: 100% (44/44), 26.50 KiB | 847.00 KiB/s, done.

# %%
# %cd /content/Crowd-Counting-Density-Based
# !mkdir test
# !unzip "/content/gdrive/MyDrive/dataset/Dataset.zip" -d "/content/Crowd-Counting-Density-Based/test/"
# Out:
# /content/Crowd-Counting-Density-Based
# mkdir: cannot create directory ‘test’: File exists
# Archive:  /content/gdrive/MyDrive/dataset/Dataset.zip
#    creating: /content/Crowd-Counting-Density-Based/test/Dataset/
#   inflating: /content/Crowd-Counting-Density-Based/test/Dataset/001.jpg
#   inflating: /content/Crowd-Counting-Density-Based/test/Dataset/002.jpg
#   inflating: /content/Crowd-Counting-Density-Based/test/Dataset/003.jpg
#   inflating: /content/Crowd-Counting-Density-Based/test/Dataset/004.jpg
#   inflating: /content/Crowd-Counting-Density-Based/test/Dataset/005.jpg
#   inflating: /content/Crowd-Counting-Density-Based/test/Dataset/006.jpg
#   inflating: /content/Crowd-Counting-Density-Based/test/Dataset/007.jpg
#   inflating: /content/Crowd-Counting-Density-Based/test/Dataset/008.jpg
#   inflating: /content/Crowd-Counting-Density-Based/test/Dataset/009.jpg
#   inflating: /content/Crowd-Counting-Density-Based/test/Dataset/010.jpg
# ...

# %%
# load dataset and model
# !mkdir bestmodel 
# !mkdir output
# !unzip "/content/gdrive/MyDrive/dataset/Paper's_weights_UCF_QNRF.zip" -d "/content/Crowd-Counting-Density-Based/bestmodel/"
# Out:
# mkdir: cannot create directory ‘bestmodel’: File exists
# mkdir: cannot create directory ‘output’: File exists
# Archive:  /content/gdrive/MyDrive/dataset/Paper's_weights_UCF_QNRF.zip
#    creating: /content/Crowd-Counting-Density-Based/bestmodel/Paper's_weights_UCF_QNRF/
#   inflating: /content/Crowd-Counting-Density-Based/bestmodel/__MACOSX/._Paper's_weights_UCF_QNRF
#   inflating: /content/Crowd-Counting-Density-Based/bestmodel/Paper's_weights_UCF_QNRF/best_M-SFANet*_UCF_QNRF.pth
#   inflating: /content/Crowd-Counting-Density-Based/bestmodel/__MACOSX/Paper's_weights_UCF_QNRF/._best_M-SFANet*_UCF_QNRF.pth
#   inflating: /content/Crowd-Counting-Density-Based/bestmodel/Paper's_weights_UCF_QNRF/.DS_Store
#   inflating: /content/Crowd-Counting-Density-Based/bestmodel/__MACOSX/Paper's_weights_UCF_QNRF/._.DS_Store
#   inflating: /content/Crowd-Counting-Density-Based/bestmodel/Paper's_weights_UCF_QNRF/best_M-SegNet*_UCF_QNRF.pth
# ...

# %%
# %cd output
# !mkdir images 
# !mkdir predicted
# %cd ..
# Out:
# /content/Crowd-Counting-Density-Based/output
# mkdir: cannot create directory ‘images’: File exists
# mkdir: cannot create directory ‘predicted’: File exists
# /content/Crowd-Counting-Density-Based

# %%
# !python3 detect.py
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/nn/functional.py:2952: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# /usr/local/lib/python3.8/dist-packages/torch/nn/functional.py:3060: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   warnings.warn("Default upsampling behavior when mode={} is changed "
# /usr/local/lib/python3.8/dist-packages/torch/nn/functional.py:1639: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# ...
